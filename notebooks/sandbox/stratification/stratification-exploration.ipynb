# %%
# %pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 3.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 3.1 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
import geopandas as gpd
import rasterio

# %%
#links to input and output directories
input_dir = "/workspace/notebooks/sandbox/data/stratification"
dem_input_dir = os.path.join(input_dir, "dem-input")
slga_input_dir = os.path.join(input_dir, "slga-input")
indices_input_dir = os.path.join(input_dir, "indices-input")

output_dir = "/workspace/notebooks/sandbox/data/stratification/output"

# %%
# import geometry for area of interest

input_aoi = os.path.join(input_data_dir, "dpird-test2.shp")

aoi_gpd = gpd.read_file(input_aoi)
