# %%
#%pip install jupyter_bokeh -q
#%pip install dask-expr -q
#%pip install datashader -q

# %%
import os
import json
import pandas as pd
import numpy as np
import geopandas as gpd

from geodata_fetch import settingshandler, harvest
from IPython.display import display, JSON

import holoviews as hv
#import hvplot.xarray
import geoviews as gv
import rioxarray
import panel as pn

hv.extension('bokeh')
gv.extension('bokeh')
pn.extension()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1009'>
#   <div id="db7a71a6-fc0e-4033-b342-78668e576ef6" data-root-id="p1009" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"680e8c54-dded-4978-bbab-21cab55c57ab":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1009"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1010","attributes":{"plot_id":"p1009","comm_id":"2683a857c4684df88786378e81246e23","client_comm_id":"5a49db23f18e4e50aad5924e2e9488c7"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"680e8c54-dded-4978-bbab-21cab55c57ab","roots":{"p1009":"db7a71a6-fc0e-4033-b342-78668e576ef6"},"root_ids":["p1009"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Function to list all .tif files in the specified directory
def list_tif_files(path):
    return [f for f in os.listdir(path) if f.endswith('.tif')]

# Function to load and display the selected .tif file
def load_and_display_tif(filename):
    filepath = os.path.join(data_load_path, filename)
    img = gv.util.from_xarray(rioxarray.open_rasterio(filepath).rio.reproject('EPSG:3857'))
    
    # Define map tiles and create the map image
    map_tiles = gv.tile_sources.EsriImagery().opts(width=1000, height=600)
    map_img = gv.Image(img, kdims=['x', 'y']).opts(cmap='viridis', title=filename)
    map_combo = map_tiles * map_img
    
    return map_combo

# %%
# notebooks/sandbox/data

property_name = 'nannup_truffles'

file_path = '/workspace/notebooks/sandbox/adhoc_client_work/nannup_truffles/map.geojson'
geom = gpd.read_file(file_path)
gpd_lon = geom.centroid.x[0]
gpd_lat = geom.centroid.y[0]


bbox = list(geom.total_bounds)
# Out:
# /tmp/ipykernel_901/1299878991.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gpd_lon = geom.centroid.x[0]
# /tmp/ipykernel_901/1299878991.py:8: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gpd_lat = geom.centroid.y[0]

# %%
geom.plot()
# Out:
# <Axes: >

# %%
test_buffer = geom.buffer(0.002, resolution =16, join_style=2)
test_buffer.plot()
# Out:
# /tmp/ipykernel_901/559881370.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   test_buffer = geom.buffer(0.002, resolution =16, join_style=2)
# <Axes: >

# %%
# Path to output directory (will be created if it doesn't exist):
outpath = '/workspace/notebooks/sandbox/adhoc_client_work/nannup_truffles'

# Column names for latitude and longitude in input file:
colname_lat = gpd_lat
colname_lng = gpd_lon

add_buffer = True
resample = True

# Bounding box: Left (min Long), Bottom (min Lat), Right (max Long), Top (max Lat)
target_bbox = bbox
# Resolution of data download in arcseconds (1 arcsec ~ 30m)

target_proj = "EPSG:3857"
target_res = 3

date_start = "2023-01-01"
date_end = "2024-01-01"
# Number of time intervals to split the image collection into
time_intervals = 0

target_sources = {"DEM":"DEM",
                  "SLGA":{
                      "Bulk_Density": ["0-5cm","5-15cm"],
                      "Organic_Carbon": ["0-5cm","5-15cm"],
                      "Clay": ["0-5cm","5-15cm"],
                      "Silt": ["0-5cm","5-15cm"],
                      "Sand": ["0-5cm","5-15cm"],
                      "Available_Water_Capacity": ["0-5cm","5-15cm"],
                      "Total_Nitrogen": ["0-5cm","5-15cm"],
                      "Total_Phosphorus": ["0-5cm","5-15cm"]
                  },
                  "Radiometric":["radmap2019_grid_k_conc_filtered_awags_rad_2019",
                                 "radmap2019_grid_th_conc_filtered_awags_rad_2019",
                                 "radmap2019_grid_u_conc_filtered_awags_rad_2019"]}

data_mask=True

colname_lng
# Out:
# 115.8004025950942

# %%
# Conversion to desired JSON format
"""
TODO: add default date inside appropriate function in harvest.py instead of here.
"""
json_data = {
    "property_name":property_name,
    "outpath": outpath,
    "data_mask": data_mask,
    "target_crs": target_proj,
    "target_res": str(target_res),
    "date_start": date_start if date_start is not None else "2022-10-01", #a date of some kind must be provided or the harvester complains
    "date_end": date_end if date_end is not None else "2022-11-30",
    "time_intervals": time_intervals,
    "target_sources": target_sources,
    "target_centroid_lat": colname_lat,
    "target_centroid_lng": colname_lng,
    "target_bbox": target_bbox,
    "add_buffer": add_buffer,
    "resample": resample
}

# %%
# Store the JSON data in a file
json_outpath = outpath
json_outpath_fname = property_name + '_' +'data_harvest_settings.json'

outfname = os.path.join(json_outpath,json_outpath_fname)

with open(outfname, "w", encoding='utf-8') as file:
    json.dump(json_data, file, ensure_ascii=False, indent=4)

# %%
# Path to file:
path_settings = outpath
# Filename
fname_settings = json_outpath_fname

infname = os.path.join(path_settings,fname_settings)

# %%
# print settings as json
settingshandler.display_settings(infname)
# Out:
# {
#     "add_buffer": true,
#     "data_mask": true,
#     "date_end": "2024-01-01",
#     "date_start": "2023-01-01",
#     "outpath": "/workspace/notebooks/sandbox/adhoc_client_work/nannup_truffles",
#     "property_name": "nannup_truffles",
#     "resample": true,
#     "target_bbox": [
#         115.79365304260892,
#         -33.797619484931424,
#         115.80339273514568,
#         -33.78405009322897
#     ],
#     "target_centroid_lat": -33.78903325699275,
#     "target_centroid_lng": 115.8004025950942,
#     "target_crs": "EPSG:3857",
#     "target_res": "3",
#     "target_sources": {
#         "DEM": "DEM",
#         "Radiometric": [
#             "radmap2019_grid_k_conc_filtered_awags_rad_2019",
#             "radmap2019_grid_th_conc_filtered_awags_rad_2019",
#             "radmap2019_grid_u_conc_filtered_awags_rad_2019"
#         ],
#         "SLGA": {
#             "Available_Water_Capacity": [
#                 "0-5cm",
#                 "5-15cm"
#             ],
#             "Bulk_Density": [
#                 "0-5cm",
#                 "5-15cm"
#             ],
#             "Clay": [
#                 "0-5cm",
#                 "5-15cm"
#             ],
#             "Organic_Carbon": [
#                 "0-5cm",
#                 "5-15cm"
#             ],
#             "Sand": [
#                 "0-5cm",
#                 "5-15cm"
#             ],
#             "Silt": [
#                 "0-5cm",
#                 "5-15cm"
#             ],
#             "Total_Nitrogen": [
#                 "0-5cm",
#                 "5-15cm"
#             ],
#             "Total_Phosphorus": [
#                 "0-5cm",
#                 "5-15cm"
#             ]
#         }
#     },
#     "time_intervals": 0
# }

# %%
# store settings as namespace (easier to interact with)
"""
TODO: have hard-coded geom for now to get masking done but the settings.json should be modified to pass the originall polygon rather than the bbox
"""
settings = settingshandler.main(infname)

# %%
df = harvest.run(infname, geom)
# Out:
# Starting the data harvester -----
# Found the following 3 sources: ['DEM', 'SLGA', 'Radiometric']
#
# Downloading from API sources -----
# Downloading SLGA data...
# SLGA_Bulk_Density_0-5cm_nannup_truffles.tif already exists, skipping download
# SLGA_Bulk_Density_5-15cm_nannup_truffles.tif already exists, skipping download
# SLGA_Organic_Carbon_0-5cm_nannup_truffles.tif already exists, skipping download
# SLGA_Organic_Carbon_5-15cm_nannup_truffles.tif already exists, skipping download
# SLGA_Clay_0-5cm_nannup_truffles.tif already exists, skipping download
# SLGA_Clay_5-15cm_nannup_truffles.tif already exists, skipping download
# SLGA_Silt_0-5cm_nannup_truffles.tif already exists, skipping download
# SLGA_Silt_5-15cm_nannup_truffles.tif already exists, skipping download
# SLGA_Sand_0-5cm_nannup_truffles.tif already exists, skipping download
# SLGA_Sand_5-15cm_nannup_truffles.tif already exists, skipping download
# /workspace/packages/geodata_utils/src/geodata_fetch/harvest.py:40: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   input_geom = input_geom.buffer(0.002, join_style=2, resolution=15)
# Downloading SLGA_Available_Water_Capacity_0-5cm_nannup_truffles.tif ▃▅▇ 0s
# Downloading SLGA_Available_Water_Capacity_0-5cm_nannup_truffles.tif 6.0s
# Downloading SLGA_Available_Water_Capacity_5-15cm_nannup_truffles.tif 2.7s
# Downloading SLGA_Total_Nitrogen_0-5cm_nannup_truffles.tif 0.3s
# Downloading SLGA_Total_Nitrogen_5-15cm_nannup_truffles.tif 0.2s
# Downloading SLGA_Total_Phosphorus_0-5cm_nannup_truffles.tif 0.3s
# Downloading SLGA_Total_Phosphorus_5-15cm_nannup_truffles.tif 0.2s
# Downloading DEM data...
# Retrieving coverage from WCS server 5.8s
# DEM_SRTM_1_Second_Hydro_Enforced_nannup_truffles.tif already exists, skipping download
# Downloading Radiometric data...
# radmap2019_grid_k_conc_filtered_awags_rad_2019.tif already exists, skipping download
# radmap2019_grid_th_conc_filtered_awags_rad_2019.tif already exists, skipping download
# radmap2019_grid_u_conc_filtered_awags_rad_2019.tif already exists, skipping download
# data mask is True
# /usr/local/lib/python3.10/site-packages/rioxarray/raster_writer.py:130: UserWarning: The nodata value (3.402823466e+38) has been automatically changed to (3.4028234663852886e+38) to match the dtype of the data.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/rioxarray/raster_writer.py:130: UserWarning: The nodata value (3.402823466e+38) has been automatically changed to (3.4028234663852886e+38) to match the dtype of the data.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/rioxarray/raster_writer.py:130: UserWarning: The nodata value (3.402823466e+38) has been automatically changed to (3.4028234663852886e+38) to match the dtype of the data.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/rioxarray/raster_writer.py:130: UserWarning: The nodata value (3.402823466e+38) has been automatically changed to (3.4028234663852886e+38) to match the dtype of the data.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/rioxarray/raster_writer.py:130: UserWarning: The nodata value (3.402823466e+38) has been automatically changed to (3.4028234663852886e+38) to match the dtype of the data.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/rioxarray/raster_writer.py:130: UserWarning: The nodata value (3.402823466e+38) has been automatically changed to (3.4028234663852886e+38) to match the dtype of the data.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/rioxarray/raster_writer.py:130: UserWarning: The nodata value (3.402823466e+38) has been automatically changed to (3.4028234663852886e+38) to match the dtype of the data.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/rioxarray/raster_writer.py:130: UserWarning: The nodata value (3.402823466e+38) has been automatically changed to (3.4028234663852886e+38) to match the dtype of the data.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/rioxarray/raster_writer.py:130: UserWarning: The nodata value (3.402823466e+38) has been automatically changed to (3.4028234663852886e+38) to match the dtype of the data.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/rioxarray/raster_writer.py:130: UserWarning: The nodata value (3.402823466e+38) has been automatically changed to (3.4028234663852886e+38) to match the dtype of the data.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/rioxarray/raster_writer.py:130: UserWarning: The nodata value (3.402823466e+38) has been automatically changed to (3.4028234663852886e+38) to match the dtype of the data.
#   warnings.warn(
# Harvest complete
# /usr/local/lib/python3.10/site-packages/rioxarray/raster_writer.py:130: UserWarning: The nodata value (3.402823466e+38) has been automatically changed to (3.4028234663852886e+38) to match the dtype of the data.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/rioxarray/raster_writer.py:130: UserWarning: The nodata value (3.402823466e+38) has been automatically changed to (3.4028234663852886e+38) to match the dtype of the data.
#   warnings.warn(

# %%
# Create the dropdown menu
data_load_path = outpath + '/masked-data'
tif_files = list_tif_files(data_load_path)

dropdown = pn.widgets.Select(name='Select a .tif file', options=tif_files)

# Panel DynamicMap to update the map based on the dropdown selection
@pn.depends(dropdown.param.value)
def update_map(selected_file):
    return load_and_display_tif(selected_file)

# Layout using Panel
layout = pn.Column(
    pn.Row(pn.Column('## Geodata file viewer', dropdown)),
    update_map
)

# Display the Panel dashboard
layout.servable()
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'5f960a25-ff42-4bd0-bf52-4bf3ec3a6540': {'version…
