# %% [markdown]
# # Dynamic Tiling of STAC assets hosted in AWS
#
# Please note that while this notebook shows HOW we can get data from AWS and do spectral index calculations without having to process and store the geotiff ourselves, this notebook does not currently include any kind of cloud masking.
#
# Cloud masking is needed for actually using these indices, as otherwise the pixels with cloud data mess up the 'valid' pixels. There is a cloud masking function in some of the other notebooks that are targeted to spectral indices.
#
# ## To do:
# - Add cloud masking before index calculation
# - rio-tiler also works with xarray, which means we should be able to use it with `odc-stac` to make single epoch and composite images. (meaning we can replicate EOS)
# - Currently using the developmentseed titiler endpoint. Need to get our own titiler endpoint working in the dev container instead.

# %%
# Uncomment this line if you need to install the dependencies
# %pip install folium requests rasterio pystac-client -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import httpx
import json
import datetime
import pprint as pp
import urllib.parse
import itertools
import pystac_client

from rio_tiler.io import STACReader
from rio_tiler.models import ImageData

from rasterio.features import bounds as featureBounds

from folium import Map, TileLayer, GeoJson

# %%
def initialize_stac_client(stac_url):
    """
    Initialize and return a STAC client for a given STAC API URL.
    Parameters:
    - stac_url (str): The URL of the STAC API.
    Returns:
    - A pystac_client.Client object
    """
    client = pystac_client.Client.open(stac_url)
    return client


def query_stac_api(client, collections, bbox, start_date=None, end_date=None, max_items=100):
    """
    Query a STAC API for items within a bounding box and date range for specific collections.
    Parameters:
    - client: The STAC client initialized with `initialize_stac_client`.
    - bbox (list): The bounding box for the query [min_lon, min_lat, max_lon, max_lat].
    - collections (list): A list of collection IDs to include in the query.
    - start_date (str, optional): The start date for the query (YYYY-MM-DD). Defaults to None.
    - end_date (str, optional): The end date for the query (YYYY-MM-DD). Defaults to None.
    - limit (int): Maximum number of items to return.    
    Returns:
    - A list of STAC Items that match the query parameters.
    """

    search_params = {
        "bbox": bbox,
        "collections": [collections],
        "max_items": max_items
    }
    if start_date and end_date:
        search_params["datetime"] = f"{start_date}/{end_date}"

    search = client.search(**search_params).item_collection()
    return search

# %%
titiler_endpoint = "https://titiler.xyz"  # Developmentseed Demo endpoint. Please be kind.
stac_endpoint = "https://earth-search.aws.element84.com/v1"

collection_sentinel = "sentinel-2-l2a"

start_date = "2024-05-20"
end_date = "2024-05-28"
sentinel_bands = ['blue','green','red','nir', 'rededge1', 'swir16', 'scl']

# %%
geojson = {
    'body': {
        "type": "FeatureCollection",
        "name": "dissolved-boundaries",
        "crs": {
            "type": "name",
            "properties": {
                "name": "urn:ogc:def:crs:OGC:1.3:CRS84" 
            }
        },
        "features": [
            {
                "type": "Feature",
                "properties": {
                    "fid": 1
                },
                "geometry": {
                    "type": "Polygon",
                    "coordinates": [
                        [
                            [116.26012130269045, -29.225295369642396],
                            [116.261724812149055, -29.241374854584375],
                            [116.283751968396274, -29.256813692452539],
                            [116.284342735038919, -29.268250184258388],
                            [116.292247755352392, -29.265992437426529],
                            [116.292360282331941, -29.293057573630019],
                            [116.314865678242256, -29.293523728033122],
                            [116.326259034921833, -29.293033039128805],
                            [116.326315298411629, -29.305397680579894],
                            [116.355065941687045, -29.307016748931797],
                            [116.355065941687045, -29.306575187382712],
                            [116.383366477044206, -29.307384715430175],
                            [116.384322956370426, -29.290407813444993],
                            [116.387586238777402, -29.282629879611861],
                            [116.386517232471661, -29.259807919053017],
                            [116.359201308185533, -29.259488866292969],
                            [116.359229439930417, -29.259243440415627],
                            [116.35242155766754, -29.259292525638209],
                            [116.352140240218716, -29.220237788279107],
                            [116.302234524787593, -29.223503148505326],
                            [116.281388901825679, -29.2239696200396],
                            [116.26012130269045, -29.225295369642396]
                        ]
                    ]
                }
            }
        ]
    }
}

req = geojson
geojson_data = req['body'] 

bounds = featureBounds(geojson_data)
print(bounds)
# Out:
# (116.26012130269045, -29.307384715430175, 116.3875862387774, -29.220237788279107)

# %%
# check polygon on map before proceeding
m = Map(
    tiles="OpenStreetMap",
    location=((bounds[1] + bounds[3]) / 2,(bounds[0] + bounds[2]) / 2),
    zoom_start=12
)

geo_json = GeoJson(data=geojson_data)
geo_json.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56ac7d9012d72704253978911ab38bd1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56ac7d9012d72704253978911ab38bd1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56ac7d9012d72704253978911ab38bd1 = L.map(
#                 &quot;map_56ac7d9012d72704253978911ab38bd1&quot;,
#                 {
#                     center: [-29.26381125185464, 116.32385377073393],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1d0a37813802f2430573463387b8520e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1d0a37813802f2430573463387b8520e.addTo(map_56ac7d9012d72704253978911ab38bd1);
#
#
#
#         function geo_json_2ff634922da98a71b216971a1540ab4f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2ff634922da98a71b216971a1540ab4f = L.geoJson(null, {
#                 onEachFeature: geo_json_2ff634922da98a71b216971a1540ab4f_onEachFeature,
#
#         });
#
#         function geo_json_2ff634922da98a71b216971a1540ab4f_add (data) {
#             geo_json_2ff634922da98a71b216971a1540ab4f
#                 .addData(data);
#         }
#             geo_json_2ff634922da98a71b216971a1540ab4f_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:OGC:1.3:CRS84&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[116.26012130269045, -29.225295369642396], [116.26172481214905, -29.241374854584375], [116.28375196839627, -29.25681369245254], [116.28434273503892, -29.268250184258388], [116.29224775535239, -29.26599243742653], [116.29236028233194, -29.29305757363002], [116.31486567824226, -29.293523728033122], [116.32625903492183, -29.293033039128805], [116.32631529841163, -29.305397680579894], [116.35506594168704, -29.307016748931797], [116.35506594168704, -29.306575187382712], [116.3833664770442, -29.307384715430175], [116.38432295637043, -29.290407813444993], [116.3875862387774, -29.28262987961186], [116.38651723247166, -29.259807919053017], [116.35920130818553, -29.25948886629297], [116.35922943993042, -29.259243440415627], [116.35242155766754, -29.25929252563821], [116.35214024021872, -29.220237788279107], [116.3022345247876, -29.223503148505326], [116.28138890182568, -29.2239696200396], [116.26012130269045, -29.225295369642396]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;fid&quot;: 1}, &quot;type&quot;: &quot;Feature&quot;}], &quot;name&quot;: &quot;dissolved-boundaries&quot;, &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_2ff634922da98a71b216971a1540ab4f.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_2ff634922da98a71b216971a1540ab4f.addTo(map_56ac7d9012d72704253978911ab38bd1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# STAC query to get items

client_sentinel = initialize_stac_client(stac_endpoint)
items_sentinel = query_stac_api(client_sentinel, collection_sentinel, bounds, start_date, end_date)

# %%
items_sentinel
# Out:
# <style>
# .pystac-summary {
#     cursor: pointer;
#     display: list-item;
#     list-style: revert;
#     margin-bottom: 0 !important;
#
#     .pystac-l {
#         padding-left: 0.5em;
#         color: rgb(64, 128, 128);
#         font-style: italic;
#     }
# }
# .pystac-row {
#     overflow-wrap: break-word;
#     padding-left: .825em;
#
#     .pystac-k {
#         display: inline-block;
#         margin: 0px 0.5em 0px 0px;
#     }
#     .pystac-v {
#         color: rgb(186, 33, 33);
#     }
# }
# .pystac-k {
#     color: rgb(0, 128, 0);
#     font-weight: 700;
# }
# </style>
# <div class="jp-RenderedJSON jp-mod-trusted jp-OutputArea-output">
#     <div class="container" style="line-height: normal;">
#         <ul style="padding: 0px; margin: 0px; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">type</span>
#             <span class="pystac-v">"FeatureCollection"</span>
#         </li>
#
#
#
#
#                     <li><details>
#         <summary class="pystac-summary"><span class="pystac-k">features</span><span class="pystac-l">[] 2 items</span></summary>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li><details>
#             <summary class="pystac-summary"><span class="pystac-k">0</span></summary>
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">type</span>
#             <span class="pystac-v">"Feature"</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">stac_version</span>
#             <span class="pystac-v">"1.0.0"</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">id</span>
#             <span class="pystac-v">"S2B_50JMN_20240525_0_L2A"</span>
#         </li>
#
#
#
#
#
#         <li><details>
#             <summary class="pystac-summary"><span class="pystac-k">properties</span></summary>
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">created</span>
#             <span class="pystac-v">"2024-05-28T17:49:24.961Z"</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">platform</span>
#             <span class="pystac-v">"sentinel-2b"</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">constellation</span>
#             <span class="pystac-v">"sentinel-2"</span>
#         </li>
#
#
#
#
#                 <li><details>
#         <summary class="pystac-summary"><span class="pystac-k">instruments</span><span class="pystac-l">[] 1 items</span></summary>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">0</span>
#             <span class="pystac-v">"msi"</span>
#         </li>
#
#
#
#     </ul>
#
#     </details></li>
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">eo:cloud_cover</span>
#             <span class="pystac-v">22.190964</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">proj:epsg</span>
#             <span class="pystac-v">32750</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">mgrs:utm_zone</span>
#             <span class="pystac-v">50</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">mgrs:latitude_band</span>
#             <span class="pystac-v">"J"</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">mgrs:grid_square</span>
#             <span class="pystac-v">"MN"</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">grid:code</span>
#             <span class="pystac-v">"MGRS-50JMN"</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">view:sun_azimuth</span>
#             <span class="pystac-v">29.6806864974649</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">view:sun_elevation</span>
#             <span class="pystac-v">33.5811834941601</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">s2:degraded_msi_data_percentage</span>
#             <span class="pystac-v">0.0009</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">s2:nodata_pixel_percentage</span>
#             <span class="pystac-v">0</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">s2:saturated_defective_pixel_percentage</span>
#             <span class="pystac-v">0</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">s2:dark_features_percentage</span>
#             <span class="pystac-v">0.001118</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">s2:cloud_shadow_percentage</span>
#             <span class="pystac-v">0.641186</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">s2:vegetation_percentage</span>
#             <span class="pystac-v">0.043776</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">s2:not_vegetated_percentage</span>
#             <span class="pystac-v">75.324023</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">s2:water_percentage</span>
#             <span class="pystac-v">1.018988</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">s2:unclassified_percentage</span>
#             <span class="pystac-v">0.779944</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">s2:medium_proba_clouds_percentage</span>
#             <span class="pystac-v">6.103795</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">s2:high_proba_clouds_percentage</span>
#             <span class="pystac-v">16.059721</span>
#         </li>
#
#
#
#
#
#         <li class="pystac-row">
#             <span class="pystac-k">s2:thin_cirrus_percentage</span>
#             <span class="pystac-v">0.027448</span>
#         </li>

# %% [markdown]
# pystac item [options](https://pystac.readthedocs.io/en/latest/api/pystac.html#pystac.Item)

# %%
for item in items_sentinel:
    print(item.id)
    pp.pp(item.links[0])
    pp.pp(item.assets)
    pp.pp(item.geometry)
    print()
# Out:
# S2B_50JMN_20240525_0_L2A
# <Link rel=self target=https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2B_50JMN_20240525_0_L2A>
# {'aot': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2B_50JMN_20240525_0_L2A/AOT.tif>,
#  'blue': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2B_50JMN_20240525_0_L2A/B02.tif>,
#  'coastal': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2B_50JMN_20240525_0_L2A/B01.tif>,
#  'granule_metadata': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2B_50JMN_20240525_0_L2A/granule_metadata.xml>,
#  'green': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2B_50JMN_20240525_0_L2A/B03.tif>,
#  'nir': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2B_50JMN_20240525_0_L2A/B08.tif>,
#  'nir08': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2B_50JMN_20240525_0_L2A/B8A.tif>,
#  'nir09': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2B_50JMN_20240525_0_L2A/B09.tif>,
#  'red': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2B_50JMN_20240525_0_L2A/B04.tif>,
#  'rededge1': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2B_50JMN_20240525_0_L2A/B05.tif>,
#  'rededge2': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2B_50JMN_20240525_0_L2A/B06.tif>,
#  'rededge3': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2B_50JMN_20240525_0_L2A/B07.tif>,
#  'scl': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2B_50JMN_20240525_0_L2A/SCL.tif>,
#  'swir16': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2B_50JMN_20240525_0_L2A/B11.tif>,
#  'swir22': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2B_50JMN_20240525_0_L2A/B12.tif>,
#  'thumbnail': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2B_50JMN_20240525_0_L2A/thumbnail.jpg>,
#  'tileinfo_metadata': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2B_50JMN_20240525_0_L2A/tileinfo_metadata.json>,
#  'visual': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2B_50JMN_20240525_0_L2A/TCI.tif>,
#  'wvp': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2B_50JMN_20240525_0_L2A/WVP.tif>,
#  'aot-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/25/0/AOT.jp2>,
#  'blue-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/25/0/B02.jp2>,
#  'coastal-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/25/0/B01.jp2>,
#  'green-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/25/0/B03.jp2>,
#  'nir-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/25/0/B08.jp2>,
#  'nir08-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/25/0/B8A.jp2>,
#  'nir09-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/25/0/B09.jp2>,
#  'red-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/25/0/B04.jp2>,
#  'rededge1-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/25/0/B05.jp2>,
#  'rededge2-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/25/0/B06.jp2>,
#  'rededge3-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/25/0/B07.jp2>,
#  'scl-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/25/0/SCL.jp2>,
#  'swir16-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/25/0/B11.jp2>,
#  'swir22-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/25/0/B12.jp2>,
#  'visual-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/25/0/TCI.jp2>,
#  'wvp-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/25/0/WVP.jp2>}
# {'type': 'Polygon',
#  'coordinates': [[[115.97368570868552, -28.92383860332918],
#                   [115.96367842312942, -29.914648530459772],
#                   [117.10110203481305, -29.918681913726438],
#                   [117.10012553061785, -28.927712966860092],
#                   [115.97368570868552, -28.92383860332918]]]}
#
# S2A_50JMN_20240520_0_L2A
# <Link rel=self target=https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2A_50JMN_20240520_0_L2A>
# {'aot': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2A_50JMN_20240520_0_L2A/AOT.tif>,
#  'blue': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2A_50JMN_20240520_0_L2A/B02.tif>,
#  'coastal': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2A_50JMN_20240520_0_L2A/B01.tif>,
#  'granule_metadata': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2A_50JMN_20240520_0_L2A/granule_metadata.xml>,
#  'green': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2A_50JMN_20240520_0_L2A/B03.tif>,
#  'nir': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2A_50JMN_20240520_0_L2A/B08.tif>,
#  'nir08': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2A_50JMN_20240520_0_L2A/B8A.tif>,
#  'nir09': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2A_50JMN_20240520_0_L2A/B09.tif>,
#  'red': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2A_50JMN_20240520_0_L2A/B04.tif>,
#  'rededge1': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2A_50JMN_20240520_0_L2A/B05.tif>,
#  'rededge2': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2A_50JMN_20240520_0_L2A/B06.tif>,
#  'rededge3': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2A_50JMN_20240520_0_L2A/B07.tif>,
#  'scl': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2A_50JMN_20240520_0_L2A/SCL.tif>,
#  'swir16': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2A_50JMN_20240520_0_L2A/B11.tif>,
#  'swir22': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2A_50JMN_20240520_0_L2A/B12.tif>,
#  'thumbnail': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2A_50JMN_20240520_0_L2A/thumbnail.jpg>,
#  'tileinfo_metadata': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2A_50JMN_20240520_0_L2A/tileinfo_metadata.json>,
#  'visual': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2A_50JMN_20240520_0_L2A/TCI.tif>,
#  'wvp': <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2A_50JMN_20240520_0_L2A/WVP.tif>,
#  'aot-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/20/0/AOT.jp2>,
#  'blue-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/20/0/B02.jp2>,
#  'coastal-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/20/0/B01.jp2>,
#  'green-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/20/0/B03.jp2>,
#  'nir-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/20/0/B08.jp2>,
#  'nir08-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/20/0/B8A.jp2>,
#  'nir09-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/20/0/B09.jp2>,
#  'red-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/20/0/B04.jp2>,
#  'rededge1-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/20/0/B05.jp2>,
#  'rededge2-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/20/0/B06.jp2>,
#  'rededge3-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/20/0/B07.jp2>,
#  'scl-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/20/0/SCL.jp2>,
#  'swir16-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/20/0/B11.jp2>,
#  'swir22-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/20/0/B12.jp2>,
#  'visual-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/20/0/TCI.jp2>,
#  'wvp-jp2': <Asset href=s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/20/0/WVP.jp2>}
# {'type': 'Polygon',
#  'coordinates': [[[115.97368570868552, -28.92383860332918],
#                   [115.96367842312942, -29.914648530459772],
#                   [117.10110203481305, -29.918681913726438],
#                   [117.10012553061785, -28.927712966860092],
#                   [115.97368570868552, -28.92383860332918]]]}

# %%
bounds = featureBounds(item)

m = Map(
    tiles="OpenStreetMap",
    location=((bounds[1] + bounds[3]) / 2,(bounds[0] + bounds[2]) / 2),
    zoom_start=8
)

geo_json = GeoJson(data=item)
geo_json.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e77dfd946030fe6e10981ad903925e15 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e77dfd946030fe6e10981ad903925e15&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e77dfd946030fe6e10981ad903925e15 = L.map(
#                 &quot;map_e77dfd946030fe6e10981ad903925e15&quot;,
#                 {
#                     center: [-29.42126025852781, 116.53239022897124],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_03094da3eecd04ad9d23de4c02424c8b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_03094da3eecd04ad9d23de4c02424c8b.addTo(map_e77dfd946030fe6e10981ad903925e15);
#
#
#
#         function geo_json_72f4551d67c40e7df373a13a0389bf46_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_72f4551d67c40e7df373a13a0389bf46 = L.geoJson(null, {
#                 onEachFeature: geo_json_72f4551d67c40e7df373a13a0389bf46_onEachFeature,
#
#         });
#
#         function geo_json_72f4551d67c40e7df373a13a0389bf46_add (data) {
#             geo_json_72f4551d67c40e7df373a13a0389bf46
#                 .addData(data);
#         }
#             geo_json_72f4551d67c40e7df373a13a0389bf46_add({&quot;assets&quot;: {&quot;aot&quot;: {&quot;href&quot;: &quot;https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2A_50JMN_20240520_0_L2A/AOT.tif&quot;, &quot;proj:shape&quot;: [5490, 5490], &quot;proj:transform&quot;: [20, 0, 399960, 0, -20, 6800020], &quot;raster:bands&quot;: [{&quot;bits_per_sample&quot;: 15, &quot;data_type&quot;: &quot;uint16&quot;, &quot;nodata&quot;: 0, &quot;offset&quot;: 0, &quot;scale&quot;: 0.001, &quot;spatial_resolution&quot;: 20}], &quot;roles&quot;: [&quot;data&quot;, &quot;reflectance&quot;], &quot;title&quot;: &quot;Aerosol optical thickness (AOT)&quot;, &quot;type&quot;: &quot;image/tiff; application=geotiff; profile=cloud-optimized&quot;}, &quot;aot-jp2&quot;: {&quot;href&quot;: &quot;s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/20/0/AOT.jp2&quot;, &quot;proj:shape&quot;: [5490, 5490], &quot;proj:transform&quot;: [20, 0, 399960, 0, -20, 6800020], &quot;raster:bands&quot;: [{&quot;bits_per_sample&quot;: 15, &quot;data_type&quot;: &quot;uint16&quot;, &quot;nodata&quot;: 0, &quot;offset&quot;: 0, &quot;scale&quot;: 0.001, &quot;spatial_resolution&quot;: 20}], &quot;roles&quot;: [&quot;data&quot;, &quot;reflectance&quot;], &quot;title&quot;: &quot;Aerosol optical thickness (AOT)&quot;, &quot;type&quot;: &quot;image/jp2&quot;}, &quot;blue&quot;: {&quot;eo:bands&quot;: [{&quot;center_wavelength&quot;: 0.49, &quot;common_name&quot;: &quot;blue&quot;, &quot;description&quot;: &quot;Blue (band 2)&quot;, &quot;full_width_half_max&quot;: 0.098, &quot;name&quot;: &quot;blue&quot;}], &quot;gsd&quot;: 10, &quot;href&quot;: &quot;https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2A_50JMN_20240520_0_L2A/B02.tif&quot;, &quot;proj:shape&quot;: [10980, 10980], &quot;proj:transform&quot;: [10, 0, 399960, 0, -10, 6800020], &quot;raster:bands&quot;: [{&quot;bits_per_sample&quot;: 15, &quot;data_type&quot;: &quot;uint16&quot;, &quot;nodata&quot;: 0, &quot;offset&quot;: -0.1, &quot;scale&quot;: 0.0001, &quot;spatial_resolution&quot;: 10}], &quot;roles&quot;: [&quot;data&quot;, &quot;reflectance&quot;], &quot;title&quot;: &quot;Blue (band 2) - 10m&quot;, &quot;type&quot;: &quot;image/tiff; application=geotiff; profile=cloud-optimized&quot;}, &quot;blue-jp2&quot;: {&quot;eo:bands&quot;: [{&quot;center_wavelength&quot;: 0.49, &quot;common_name&quot;: &quot;blue&quot;, &quot;description&quot;: &quot;Blue (band 2)&quot;, &quot;full_width_half_max&quot;: 0.098, &quot;name&quot;: &quot;blue&quot;}], &quot;gsd&quot;: 10, &quot;href&quot;: &quot;s3://sentinel-s2-l2a/tiles/50/J/MN/2024/5/20/0/B02.jp2&quot;, &quot;proj:shape&quot;: [10980, 10980], &quot;proj:transform&quot;: [10, 0, 399960, 0, -10, 6800020], &quot;raster:bands&quot;: [{&quot;bits_per_sample&quot;: 15, &quot;data_type&quot;: &quot;uint16&quot;, &quot;nodata&quot;: 0, &quot;offset&quot;: -0.1, &quot;scale&quot;: 0.0001, &quot;spatial_resolution&quot;: 10}], &quot;roles&quot;: [&quot;data&quot;, &quot;reflectance&quot;], &quot;title&quot;: &quot;Blue (band 2) - 10m&quot;, &quot;type&quot;: &quot;image/jp2&quot;}, &quot;coastal&quot;: {&quot;eo:bands&quot;: [{&quot;center_wavelength&quot;: 0.443, &quot;common_name&quot;: &quot;coastal&quot;, &quot;description&quot;: &quot;Coastal aerosol (band 1)&quot;, &quot;full_width_half_max&quot;: 0.027, &quot;name&quot;: &quot;coastal&quot;}], &quot;gsd&quot;: 60, &quot;href&quot;: &quot;https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/50/J/MN/2024/5/S2A_50JMN_20240520_0_L2A/B01.tif&quot;, &quot;proj:shape&quot;: [1

# %%
# Get Tile URL
r = httpx.get(
    f"{titiler_endpoint}/stac/info",
    params = (
        ("url", item.links[0].href),
        # Get info for multiple assets
        ("assets","visual"), ("assets","red"), ("assets","blue"), ("assets","green"),
    )
).json()
pp.pp(r)
# Out:
# {'visual': {'bounds': [115.96366797192765,
#                        -29.91872967517731,
#                        117.10111240379487,
#                        -28.923829500519567],
#             'minzoom': 8,
#             'maxzoom': 14,
#             'band_metadata': [['b1', {}], ['b2', {}], ['b3', {}]],
#             'band_descriptions': [['b1', ''], ['b2', ''], ['b3', '']],
#             'dtype': 'uint8',
#             'nodata_type': 'Nodata',
#             'colorinterp': ['red', 'green', 'blue'],
#             'scales': [1.0, 1.0, 1.0],
#             'offsets': [0.0, 0.0, 0.0],
#             'driver': 'GTiff',
#             'count': 3,
#             'width': 10980,
#             'height': 10980,
#             'overviews': [2, 4, 8, 16],
#             'nodata_value': 0.0},
#  'red': {'bounds': [115.96366797192765,
#                     -29.91872967517731,
#                     117.10111240379487,
#                     -28.923829500519567],
#          'minzoom': 8,
#          'maxzoom': 14,
#          'band_metadata': [['b1', {}]],
#          'band_descriptions': [['b1', '']],
#          'dtype': 'uint16',
#          'nodata_type': 'Nodata',
#          'colorinterp': ['gray'],
#          'scales': [1.0],
#          'offsets': [0.0],
#          'driver': 'GTiff',
#          'count': 1,
#          'width': 10980,
#          'height': 10980,
#          'overviews': [2, 4, 8, 16],
#          'nodata_value': 0.0},
#  'blue': {'bounds': [115.96366797192765,
#                      -29.91872967517731,
#                      117.10111240379487,
#                      -28.923829500519567],
#           'minzoom': 8,
#           'maxzoom': 14,
#           'band_metadata': [['b1', {}]],
#           'band_descriptions': [['b1', '']],
#           'dtype': 'uint16',
#           'nodata_type': 'Nodata',
#           'colorinterp': ['gray'],
#           'scales': [1.0],
#           'offsets': [0.0],
#           'driver': 'GTiff',
#           'count': 1,
#           'width': 10980,
#           'height': 10980,
#           'overviews': [2, 4, 8, 16],
#           'nodata_value': 0.0},
#  'green': {'bounds': [115.96366797192765,
#                       -29.91872967517731,
#                       117.10111240379487,
#                       -28.923829500519567],
#            'minzoom': 8,
#            'maxzoom': 14,
#            'band_metadata': [['b1', {}]],
#            'band_descriptions': [['b1', '']],
#            'dtype': 'uint16',
#            'nodata_type': 'Nodata',
#            'colorinterp': ['gray'],
#            'scales': [1.0],
#            'offsets': [0.0],
#            'driver': 'GTiff',
#            'count': 1,
#            'width': 10980,
#            'height': 10980,
#            'overviews': [2, 4, 8, 16],
#            'nodata_value': 0.0}}

# %% [markdown]
# ### Display one asset

# %%
r = httpx.get(
    f"{titiler_endpoint}/stac/WebMercatorQuad/tilejson.json",
    params = {
        "url": item.links[0].href,
        "assets": "visual",
        "minzoom": 8,  # By default titiler will use 0
        "maxzoom": 14, # By default titiler will use 24
    }
).json()

m = Map(
    location=((bounds[1] + bounds[3]) / 2,(bounds[0] + bounds[2]) / 2),
    zoom_start=10
)

tiles = TileLayer(
    tiles=r["tiles"][0],
    min_zoom=r["minzoom"],
    max_zoom=r["maxzoom"],
    opacity=1,
    attr="ESA"
)
tiles.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_deae1ee8e4b02478f0cbdd4e5d7038b0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_deae1ee8e4b02478f0cbdd4e5d7038b0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_deae1ee8e4b02478f0cbdd4e5d7038b0 = L.map(
#                 &quot;map_deae1ee8e4b02478f0cbdd4e5d7038b0&quot;,
#                 {
#                     center: [-29.42126025852781, 116.53239022897124],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f872ca8ddc71d81180b2fd44f22a05bf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f872ca8ddc71d81180b2fd44f22a05bf.addTo(map_deae1ee8e4b02478f0cbdd4e5d7038b0);
#
#
#             var tile_layer_3c6f3aad445803b5084341b594d7349e = L.tileLayer(
#                 &quot;https://titiler.xyz/stac/tiles/WebMercatorQuad/{z}/{x}/{y}@1x?url=https%3A%2F%2Fearth-search.aws.element84.com%2Fv1%2Fcollections%2Fsentinel-2-l2a%2Fitems%2FS2A_50JMN_20240520_0_L2A\u0026assets=visual&quot;,
#                 {&quot;attribution&quot;: &quot;ESA&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 14, &quot;minZoom&quot;: 8, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3c6f3aad445803b5084341b594d7349e.addTo(map_deae1ee8e4b02478f0cbdd4e5d7038b0);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Get Tile URL
r = httpx.get(
    f"{titiler_endpoint}/stac/WebMercatorQuad/tilejson.json",
    params = (
        ("url", item.links[0].href),
        ("assets", "red"),
        ("assets", "green"),
        ("assets", "blue"),
        ("minzoom", 8),
        ("maxzoom", 14),
        ("rescale", "0,2000"),
    )
).json()

m = Map(
    location=((bounds[1] + bounds[3]) / 2,(bounds[0] + bounds[2]) / 2),
    zoom_start=11
)

tiles = TileLayer(
    tiles=r["tiles"][0],
    min_zoom=r["minzoom"],
    max_zoom=r["maxzoom"],
    opacity=1,
    attr="ESA"
)
tiles.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_faa4097270cdf9e8a65f844f4c04a385 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_faa4097270cdf9e8a65f844f4c04a385&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_faa4097270cdf9e8a65f844f4c04a385 = L.map(
#                 &quot;map_faa4097270cdf9e8a65f844f4c04a385&quot;,
#                 {
#                     center: [-29.42126025852781, 116.53239022897124],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9506d8e9b6d73c3e1300c2c8496d2160 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9506d8e9b6d73c3e1300c2c8496d2160.addTo(map_faa4097270cdf9e8a65f844f4c04a385);
#
#
#             var tile_layer_9b0447130b335e42d706bc69af73ed33 = L.tileLayer(
#                 &quot;https://titiler.xyz/stac/tiles/WebMercatorQuad/{z}/{x}/{y}@1x?url=https%3A%2F%2Fearth-search.aws.element84.com%2Fv1%2Fcollections%2Fsentinel-2-l2a%2Fitems%2FS2A_50JMN_20240520_0_L2A\u0026assets=red\u0026assets=green\u0026assets=blue\u0026rescale=0%2C2000&quot;,
#                 {&quot;attribution&quot;: &quot;ESA&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 14, &quot;minZoom&quot;: 8, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9b0447130b335e42d706bc69af73ed33.addTo(map_faa4097270cdf9e8a65f844f4c04a385);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Use an expression to calculate a band index (NDVI) based on information contained in multiple assets.

# %%
# Get Tile URL
r = httpx.get(
    f"{titiler_endpoint}/stac/WebMercatorQuad/tilejson.json",
    params = (
        ("url", item.links[0].href),
        ("expression", "(nir-red)/(nir+red)"),  # NDVI
        # We need to tell rio-tiler that each asset is a Band
        # (so it will select the first band within each asset automatically)
        ("asset_as_band", True),
        ("rescale", "-1,1"),
        ("minzoom", 8),
        ("maxzoom", 14),
        ("colormap_name", "viridis"),
    )
).json()

m = Map(
    location=((bounds[1] + bounds[3]) / 2,(bounds[0] + bounds[2]) / 2),
    zoom_start=10
)

tiles = TileLayer(
    tiles=r["tiles"][0],
    min_zoom=r["minzoom"],
    max_zoom=r["maxzoom"],
    opacity=1,
    attr="ESA"
)
tiles.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8f65b7a59d8114767aeb39efe04447f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8f65b7a59d8114767aeb39efe04447f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8f65b7a59d8114767aeb39efe04447f = L.map(
#                 &quot;map_a8f65b7a59d8114767aeb39efe04447f&quot;,
#                 {
#                     center: [-29.42126025852781, 116.53239022897124],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ca2ddeac35d8a1ba61f7bfaa4a8462c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5ca2ddeac35d8a1ba61f7bfaa4a8462c.addTo(map_a8f65b7a59d8114767aeb39efe04447f);
#
#
#             var tile_layer_6c8307bc3c04a9db37ff04f427ee1b2b = L.tileLayer(
#                 &quot;https://titiler.xyz/stac/tiles/WebMercatorQuad/{z}/{x}/{y}@1x?url=https%3A%2F%2Fearth-search.aws.element84.com%2Fv1%2Fcollections%2Fsentinel-2-l2a%2Fitems%2FS2A_50JMN_20240520_0_L2A\u0026expression=%28nir-red%29%2F%28nir%2Bred%29\u0026asset_as_band=true\u0026rescale=-1%2C1\u0026colormap_name=viridis&quot;,
#                 {&quot;attribution&quot;: &quot;ESA&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 14, &quot;minZoom&quot;: 8, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6c8307bc3c04a9db37ff04f427ee1b2b.addTo(map_a8f65b7a59d8114767aeb39efe04447f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# If you don't use the  `asset_as_band=True` option, you need to append the band to the asset name within the expression. For example, `nir` becomes `nir_b1`.

# %%
# Get Tile URL
r = httpx.get(
    f"{titiler_endpoint}/stac/WebMercatorQuad/tilejson.json",
    params = (
        ("url", item.links[0].href),
        ("expression", "(nir_b1-red_b1)/(nir_b1+red_b1)"),  # NDVI
        ("rescale", "-1,1"),
        ("minzoom", 8),
        ("maxzoom", 14),
        ("colormap_name", "viridis"),
    )
).json()

m = Map(
    location=((bounds[1] + bounds[3]) / 2,(bounds[0] + bounds[2]) / 2),
    zoom_start=10
)

tiles = TileLayer(
    tiles=r["tiles"][0],
    min_zoom=r["minzoom"],
    max_zoom=r["maxzoom"],
    opacity=1,
    attr="ESA"
)
tiles.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_559b714899aadd75419ef8769bac9814 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_559b714899aadd75419ef8769bac9814&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_559b714899aadd75419ef8769bac9814 = L.map(
#                 &quot;map_559b714899aadd75419ef8769bac9814&quot;,
#                 {
#                     center: [-29.42126025852781, 116.53239022897124],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f467c26c9f0f2e39d5225a7275b2b419 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f467c26c9f0f2e39d5225a7275b2b419.addTo(map_559b714899aadd75419ef8769bac9814);
#
#
#             var tile_layer_17f654fa4a96b4a16421fa6c9c6eb7b4 = L.tileLayer(
#                 &quot;https://titiler.xyz/stac/tiles/WebMercatorQuad/{z}/{x}/{y}@1x?url=https%3A%2F%2Fearth-search.aws.element84.com%2Fv1%2Fcollections%2Fsentinel-2-l2a%2Fitems%2FS2A_50JMN_20240520_0_L2A\u0026expression=%28nir_b1-red_b1%29%2F%28nir_b1%2Bred_b1%29\u0026rescale=-1%2C1\u0026colormap_name=viridis&quot;,
#                 {&quot;attribution&quot;: &quot;ESA&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 14, &quot;minZoom&quot;: 8, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_17f654fa4a96b4a16421fa6c9c6eb7b4.addTo(map_559b714899aadd75419ef8769bac9814);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
