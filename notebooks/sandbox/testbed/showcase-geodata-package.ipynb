# %%
import os
import json
import pandas as pd
import geopandas as gpd
from geodata_fetch import settingshandler, harvest

import hvplot.pandas
import hvplot.xarray
import holoviews as hv
import geoviews as gv
import rioxarray
from IPython.display import display, JSON

hv.extension('bokeh')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1303'>
#   <div id="c4aa5a92-535c-4051-b280-4cd9ae7517b2" data-root-id="p1303" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Path to file:
path_settings = '/workspaces/data-notebooks/notebooks/sandbox/data/output-data/geodata-package-testing'
# Filename
fname_settings = 'settings_showcase.json'

infname = os.path.join(path_settings,fname_settings)

# %%
# store settings as namespace (easier to interact with)
settings = settingshandler.main(infname)

# %%
df = harvest.run(infname, preview=True, return_df=False)
# Out:
# Starting the data harvester -----
# Found the following 1 sources: ['SLGA']
#
# ...
#
# ⌛ Downloading SLGA data...
# SLGA_Organic_Carbon_0-5cm.tif already exists, skipping download
# SLGA_Organic_Carbon_5-15cm.tif already exists, skipping download
# SLGA_Organic_Carbon_0-5cm_5percentile.tif already exists, skipping download
# SLGA_Organic_Carbon_0-5cm_95percentile.tif already exists, skipping download
# SLGA_Organic_Carbon_5-15cm_5percentile.tif already exists, skipping download
# SLGA_Organic_Carbon_5-15cm_95percentile.tif already exists, skipping download
# ...
#
# Extracting data points for test-name  -----

# %%
filename = 'SLGA_Organic_Carbon_0-5cm.tif'
filepath = os.path.join(path_settings, filename)

# %%
img = gv.util.from_xarray(rioxarray.open_rasterio(filepath).rio.reproject('EPSG:3857'))
map_tiles = hv.element.tiles.EsriImagery().opts(width=1000, height=600)
map_img = hv.Image(img, kdims=['x','y']).opts(cmap='viridis', title=filename)
map_combo = map_tiles * map_img
map_combo
# Out:
# :Overlay
#    .Tiles.I :Tiles   [x,y]
#    .Image.I :Image   [x,y]   (z)
