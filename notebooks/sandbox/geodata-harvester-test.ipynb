# %%
import os

package_path = os.path.abspath('/home/jennaguffogg/workspace/sensand/repos/data-notebooks/packages/geodata_fetch')
# !pip install -e {package_path}
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///home/jennaguffogg/workspace/sensand/repos/data-notebooks/packages/geodata_fetch
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: geodata-fetch
#     Found existing installation: geodata-fetch 0.0.1
#     Uninstalling geodata-fetch-0.0.1:
#       Successfully uninstalled geodata-fetch-0.0.1
#   Running setup.py develop for geodata-fetch
# ...
