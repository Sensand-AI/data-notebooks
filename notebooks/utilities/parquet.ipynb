# %% [markdown]
# # Create parquet files from a directoy of CSV files
#
# This notebook demonstrates how to create parquet files from a directory of CSV files using pyarrow.

# %%
import pandas as pd
import os

# Directory containing the CSV files
directory = "/workspace/notebook_outputs"
parquet_file = f"{directory}/daily_weather.parquet"

# List to hold dataframes
dataframes = []

# Walk through all directories and files in the path
for dirpath, dirnames, filenames in os.walk(directory):
    for filename in filenames:
        if filename.endswith('_daily_weather.csv'):
            # Construct full file path
            filepath = os.path.join(dirpath, filename)
            df = pd.read_csv(filepath)
            dataframes.append(df)

# Combine all dataframes into a single dataframe
combined_df_daily = pd.concat(dataframes, ignore_index=True)

# Write the combined dataframe to a Parquet file
combined_df_daily.to_parquet(parquet_file, engine='pyarrow')

# %%
# Directory containing the CSV files
directory = "/workspace/notebook_outputs"
parquet_file = f"{directory}/hourly_weather.parquet"

# List to hold dataframes
dataframes = []

# Walk through all directories and files in the path
for dirpath, dirnames, filenames in os.walk(directory):
    for filename in filenames:
        if filename.endswith('_hourly_weather.csv'):
            # Construct full file path
            filepath = os.path.join(dirpath, filename)
            df = pd.read_csv(filepath)
            dataframes.append(df)

# Combine all dataframes into a single dataframe
combined_df_hourly = pd.concat(dataframes, ignore_index=True)

# Write the combined dataframe to a Parquet file
combined_df_hourly.to_parquet(parquet_file, engine='pyarrow')

# %%
import pandas as pd
import os

# Directory containing the CSV files
directory = "/workspace/notebook_outputs"
parquet_file = f"{directory}/daily_weather_forecast.parquet"

# List to hold dataframes
dataframes = []

# Walk through all directories and files in the path
for dirpath, dirnames, filenames in os.walk(directory):
    for filename in filenames:
        if filename.endswith('_daily_weather_forecast.csv'):
            # Construct full file path
            filepath = os.path.join(dirpath, filename)
            df = pd.read_csv(filepath)
            dataframes.append(df)

# Combine all dataframes into a single dataframe
combined_df_daily_forecast = pd.concat(dataframes, ignore_index=True)

# Write the combined dataframe to a Parquet file
combined_df_daily_forecast.to_parquet(parquet_file, engine='pyarrow')
